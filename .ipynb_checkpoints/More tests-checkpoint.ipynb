# %% [markdown]
# # Notes

# %% [markdown]
# content --> senses --> index --> grammar contains verb info

# %%
import pymongo
import json
import nltk

# %%
pswrd = ''
with open('pswrd.txt') as text: pswrd = text.read()
conn_str = 'mongodb+srv://dov-db2:' + pswrd + '@apicluster.s8lqy.mongodb.net/test'
_client = pymongo.MongoClient(conn_str)
_db = _client['bavli']
jastrow = _db['dov-jastrow']
dicta_all = _db['new-dicta']

# %%
items = list(jastrow.find())

# %% [markdown]
# # POS Tagger

# %%
from utils.get_pos import *

# %%
w = list( jastrow.aggregate([{ '$sample': { 'size': 1 } }]) )[0]
no_html = remove_html(w)
no_html
# Out:
# {'headword': 'מְרוּמֶּה',
#  'rid': 'M02593',
#  'refs': ['Sanhedrin 32b:3', 'Sanhedrin 32b:4', 'Shevuot 30b:15'],
#  'content': {'senses': [{'definition': ' ( רָמָה )  fraudulent ;  דין מ׳  a case in which the court has reason to suspect legal trickery or conspiracy.  Snh. 32ᵇ .  Shebu. 30ᵇ '}],
#   'morphology': 'm.'},
#  'plural_form': [],
#  'alt_headwords': [],
#  'unvoweled': 'מרומה',
#  'word': 'מְרוּמֶּה',
#  'more_forms': [],
#  'all_forms': ['מְרוּמֶּה'],
#  'all_unvoweled': ['מרומה'],
#  '_id': ObjectId('60ca636a83050705044c939f')}

# %%
flat = flatten_dict(no_html)
flat
# Out:
# {'headword': ['מְרוּמֶּה'],
#  'rid': ['M02593'],
#  'refs': ['Sanhedrin 32b:3', 'Sanhedrin 32b:4', 'Shevuot 30b:15'],
#  'definition': [' ( רָמָה )  fraudulent ;  דין מ׳  a case in which the court has reason to suspect legal trickery or conspiracy.  Snh. 32ᵇ .  Shebu. 30ᵇ '],
#  'morphology': ['m.'],
#  'unvoweled': ['מרומה'],
#  'word': ['מְרוּמֶּה'],
#  'all_forms': ['מְרוּמֶּה'],
#  'all_unvoweled': ['מרומה'],
#  '_id': [ObjectId('60ca636a83050705044c939f')]}

# %%
all_defs = get_defs(flat['definition'])
all_defs
# Out:
# [('fraudulent',
#   'a case in which the court has reason to suspect legal trickery or conspiracy')]

# %%
for defs in all_defs:
    for d in defs:
        if d == '': continue
        print(nltk.pos_tag(nltk.word_tokenize(d)))
# Out:
# [('fraudulent', 'NN')]
# [('a', 'DT'), ('case', 'NN'), ('in', 'IN'), ('which', 'WDT'), ('the', 'DT'), ('court', 'NN'), ('has', 'VBZ'), ('reason', 'NN'), ('to', 'TO'), ('suspect', 'VB'), ('legal', 'JJ'), ('trickery', 'NN'), ('or', 'CC'), ('conspiracy', 'NN')]

# %%
tag_def(all_defs[0])
# Out:
# ('DEF', 'NN')

# %% [markdown]
# # Percentage of words in Berakhot present in Dicta

# %%
from utils.texts import Masekhet
from utils.deconstruct2 import detach_prefix

# %%
ber = Masekhet('Berakhot')

# %%
gemara_only = []
for p in range(len(ber)):
    for c in range(len(ber[p])):
        if ber.tags[p][c] == 'm' or ber.tags[p][c] == 'mc':
            continue
        gemara_only += [t for t in ber[p][c] if t not in ',.?!\'\"״-—:;׳()[]']

# %%
num_words = len(gemara_only[:100])
in_db = 0
for t in gemara_only[:100]:
    ws = detach_prefix(t)
    print(ws, end='\t')
    in_db += any([dicta_all.count_documents({'word': w+'\t'}) for w in ws])
    print(in_db)
print(in_db / num_words)
# Out:
# ['גְּמָ']	0
# ['תַּנָּא']	1
# ['הֵיכָא']	2
# ['קָאֵי', 'אֵי']	3
# ['דְּקָתָנֵי', 'תָנֵי', 'קָתָנֵי']	3
# ['מֵאֵימָתַי', 'אֵימָתַי']	3
# ['וְתוּ', 'תוּ']	3
# ['מַאי']	4
# ['שְׁנָא']	5
# ['דְּתָנֵי', 'תָנֵי']	5
# ['בְּעַרְבִית', 'עַרְבִית']	5
# ['בְּרֵישָׁא', 'רֵישָׁא']	6
# ['לִתְנֵי', 'תְנֵי']	7
# ['דְּשַׁחֲרִית', 'שַׁחֲרִית']	7
# ['בְּרֵישָׁא', 'רֵישָׁא']	8
# ['תַּנָּא']	9
# ['אַקְּרָא', 'קְּרָא']	10
# ['קָאֵי', 'אֵי']	11
# ['דִּכְתִיב', 'תִיב', 'כְתִיב']	11
# ['בְּשָׁכְבְּךָ', 'שָׁכְבְּךָ']	11
# ['וּבְקוּמֶךָ', 'קוּמֶךָ', 'בְקוּמֶךָ']	11
# ['וְהָכִי', 'י', 'הָכִי']	12
# ['קָתָנֵי', 'תָנֵי']	12
# ['זְמַן']	12
# ['קְרִיאַת']	12
# ['שְׁמַע']	13
# ['דִּשְׁכִיבָה', 'שְׁכִיבָה']	14
# ['אֵימַת']	15
# ['מִשָּׁעָה', 'שָּׁעָה']	15
# ['שֶׁהַכֹּהֲנִים', 'כֹּהֲנִים', 'הַכֹּהֲנִים']	15
# ['נִכְנָסִין']	15
# ['לֶאֱכוֹל']	15
# ['בִּתְרוּמָתָן', 'תְרוּמָתָן']	15
# ['וְאִי', 'אִי']	16
# ['בָּעֵית']	17
# ['אֵימָא']	18
# ['יָלֵיף']	19
# ['מִבְּרִיָּיתוֹ', 'רִיָּיתוֹ', 'בְּרִיָּיתוֹ']	19
# ['שֶׁל']	19
# ['עוֹלָם']	19
# ['דִּכְתִיב', 'תִיב', 'כְתִיב']	19
# ['וַיְהִי']	19
# ['עֶרֶב']	19
# ['וַיְהִי']	19
# ['בֹקֶר']	19
# ['יוֹם']	20
# ['אֶחָד']	20
# ['אִי']	21
# ['הָכִי', 'י']	22
# ['סֵיפָא']	23
# ['דְּקָתָנֵי', 'תָנֵי', 'קָתָנֵי']	23
# ['בַּשַּׁחַר']	23
# ['מְבָרֵךְ']	24
# ['שְׁתַּיִם']	24
# ['לְפָנֶיהָ', 'פָנֶיהָ']	24
# ['וְאַחַת', 'חַת', 'אַחַת']	25
# ['לְאַחֲרֶיהָ', 'חֲרֶיהָ', 'אַחֲרֶיהָ']	25
# ['בָּעֶרֶב']	25
# ['מְבָרֵךְ']	26
# ['שְׁתַּיִם']	26
# ['לְפָנֶיהָ', 'פָנֶיהָ']	26
# ['וּשְׁתַּיִם', 'שְׁתַּיִם']	26
# ['לְאַחֲרֶיהָ', 'חֲרֶיהָ', 'אַחֲרֶיהָ']	26
# ['לִתְנֵי', 'תְנֵי']	27
# ['דְּעַרְבִית', 'עַרְבִית']	27
# ['בְּרֵישָׁא', 'רֵישָׁא']	28
# ['תַּנָּא']	29
# ['פָּתַח']	30
# ['בְּעַרְבִית', 'עַרְבִית']	30
# ['וַהֲדַר']	30
# ['תָּנֵי']	31
# ['בְּשַׁחֲרִית', 'שַׁחֲרִית']	31
# ['עַד']	32
# ['דְּקָאֵי', 'אֵי', 'קָאֵי']	33
# ['בְּשַׁחֲרִית', 'שַׁחֲרִית']	33
# ['פָּרֵישׁ']	34
# ['מִילֵּי']	34
# ['דְשַׁחֲרִית']	34
# ['וַהֲדַר']	34
# ['פָּרֵישׁ']	35
# ['מִילֵּי']	35
# ['דְעַרְבִית']	35
# ['אָמַר']	36
# ['מָר']	37
# ['מִשָּׁעָה', 'שָּׁעָה']	37
# ['שֶׁהַכֹּהֲנִים', 'כֹּהֲנִים', 'הַכֹּהֲנִים']	37
# ['נִכְנָסִים']	37
# ['לֶאֱכוֹל']	37
# ['בִּתְרוּמָתָן', 'תְרוּמָתָן']	37
# ['מִכְּדִי', 'דִי', 'כְּדִי']	38
# ['כֹּהֲנִים']	38
# ['אֵימַת']	39
# ['קָא', 'א']	39
# ['אָכְלִי']	40
# ['תְּרוּמָה']	40
# ['מִשְּׁעַת', 'שְּׁעַת']	40
# ['צֵאת']	40
# ['הַכּוֹכָבִים', 'כּוֹכָבִים']	40
# ['לִתְנֵי', 'תְנֵי']	41
# ['מִשְּׁעַת', 'שְּׁעַת']	41
# 0.41

# %% [markdown]
# # Appearance of Tannaitic Corpus Words in Dicta

# %%
with open('data/rab_heb_words.txt', encoding='utf-8') as f:
    heb_words = f.read().split('\n')

# %%
for w in heb_words:
    print(w, end='\t')
    print(dicta_all.count_documents({'word': w+'\t'}))
# Out:
# ['וַיֹּאמֶר',
#  'יי',
#  'אֶל',
#  'מֹשֶׁה',
#  'וְאֶל',
#  'אַהֲרֹן',
#  'בְּאֶרֶץ',
#  'מִצְרַיִם',
#  'לֵאמֹר',
#  'שׁוֹמֵעַ',
#  'אֲנִי',
#  'שֶׁהָיָה',
#  'הַדִּבֵּר',
#  'לְמֹשֶׁה',
#  'וּלְאַהֲרֹן',
#  'כְּשֶׁהוּא',
#  'אוֹמֵר',
#  'וַיְהִי',
#  'בְּיוֹם',
#  'דִּבֶּר',
#  'מִצְרָיִם',
#  'הָיָה',
#  'וְלֹא',
#  'לְאַהֲרֹן',
#  'אִם',
#  'כֵּן',
#  'מַה',
#  'תִּלְמֹד',
#  'לוֹמַר',
#  'אֶלָּא',
#  'מְלַמֵּד',
#  'שֶׁכַּשֵּׁם',
#  'כְּלָל',
#  'לַדִּבְּרוֹת',
#  'כָּךְ',
#  'וּמִפְּנֵי',
#  'מָה',
#  'לֹא',
#  'נִדְבַּר',
#  'עִמּוֹ',
#  'מִפְּנֵי',
#  'כְבוֹדוֹ',
#  'שֶׁלְּמֹשֶׁה',
#  'נִמְצֵאתָ',
#  'מְמָעֵט',
#  'מִכָּל',
#  'הַדִּבְּרוֹת',
#  'שֶׁבַּתּוֹרָה',
#  'חוּץ',
#  'מִשְּׁלֹשָׁה',
#  'מְקוֹמוֹת',
#  'שֶׁאֵי',
#  'אֶפְשָׁר',
#  'דָּבָר',
#  'אַחֵר',
#  'לָמָּה',
#  'נֶאֱמַר',
#  'לְפִי',
#  'שֶׁהוּא',
#  'רְאֵה',
#  'נְתַתִּיךָ',
#  'אֱלֹהִים',
#  'לְפַרְעֹה',
#  'אֵין',
#  'לִי',
#  'דַּיָּן',
#  'מְנַיִן',
#  'הִקִּישׁ',
#  'מֹּשֶׁה',
#  'אַף',
#  'דְּבָרָיו',
#  'יָרֵא',
#  'כָּל',
#  'הַקּוֹדֵם',
#  'בַּמִּקְרָא',
#  'הוּא',
#  'קוֹדֵם',
#  'בַּמַּעֲשֶׂה',
#  'וּמֹשֶׁה',
#  'מַגִּיד',
#  'שֶׁשְּׁנֵיהֶם',
#  'שְׁקוּלִין',
#  'זֶה',
#  'כַּזֶּה',
#  'כַּיּוֹצֵא',
#  'בַזֶּה',
#  'אַתָּה',
#  'בְּרֵאשִׁית',
#  'בָּרָא',
#  'אֵת',
#  'הַשָּׁמַיִם',
#  'וְאֵת',
#  'הָאָרֶץ',
#  'עֲשׂוֹת',
#  'אֶרֶץ',
#  'וְשָׁמָיִם',
#  'כְּאֶחָד',
#  'בַדָּבָר',
#  'אָנֹכִי',
#  'אֱלֹהֵי',
#  'אָבִיךָ',
#  'אַבְרָהָם',
#  'יִצְחָק',
#  'וֵאלֹהֵי',
#  'יַעֲקֹב',
#  'בַּדָּבָר',
#  'חָשׁוּב',
#  'מֵחֲבֵרוֹ',
#  'וְזָכַרְתִּי',
#  'אֶת',
#  'בְּרִיתִי',
#  'יַעֲקוֹב',
#  'וְאַף',
#  'שֶׁשְּׁלָשְׁתָּן',
#  'כַּבֵּד',
#  'וְאֶת',
#  'אִמֶּךָ',
#  'אִישׁ',
#  'אִמּוֹ',
#  'וְאָבִיו',
#  'תִּירָאוּ',
#  'וִיהוֹשֻׁעַ',
#  'בִּן',
#  'נוּן',
#  'וְכָלֵב',
#  'בֶּן',
#  'יְפֻנֶּה',
#  'מִן',
#  'הַתָּרִים',
#  'קָרְעוּ',
#  'בִּגְדֵיהֶם',
#  'שׁוֹמְעֵנִי',
#  'בִּלְתִּי',
#  'כָּלֵב',
#  'הַקְּנִזִּי',
#  'שְׁקוּלִים',
#  'לַכְּרָךְ',
#  'אוֹ',
#  'אֵינוֹ',
#  'בְּתוֹךְ',
#  'הַכְּרָךְ',
#  'אֵלָיו',
#  'כְּצֵאתִי',
#  'הָעִיר',
#  'אֶפְרֹשׂ',
#  'כַּפַּי',
#  'הַקֹּלוֹת',
#  'יֶחְדָּלוּן',
#  'וְהַבָּרָד',
#  'יִהְיֶה',
#  'עוֹד',
#  'לְמַעַן',
#  'תֵּדַע',
#  'כִּי',
#  'לַיי',
#  'וַהֲלֹא',
#  'דְּבָרִים',
#  'קַל',
#  'וָחֹמֶר',
#  'וּמַה',
#  'תְּפִלָּה',
#  'הַקַּלָּה',
#  'הִתְפַּלֵּל',
#  'לָעִיר',
#  'דִּבּוּר',
#  'הֶחָמוּר',
#  'דִּין',
#  'שֶׁלֹּא',
#  'שֶׁהָיְתָה',
#  'מְלֵאָה',
#  'שִׁקּוּצִים',
#  'וְגִלּוּלִים',
#  'וְעַד',
#  'נִבְחֲרָה',
#  'יִשְׂרָאֵל',
#  'הָיוּ',
#  'הָאֲרָצוֹת',
#  'כְּשֵׁרוֹת',
#  'מִשְּׁנִּבְחֲרָה',
#  'יָצְאוּ',
#  'עַד',
#  'יְרוּשָׁלַיִם',
#  'הָיְתָה',
#  'כָל',
#  'כְּשֵׁרָה',
#  'לַמִּזְבְּחוֹת',
#  'יָצָאת',
#  'שֶׁנֶּאֱמַר',
#  'הִשָּׁמֶר',
#  'לְךָ',
#  'פֶּן',
#  'תַּעֲלֶה',
#  'עֹלֹתֶיךָ',
#  'בְּכָל',
#  'מָקוֹם',
#  'אֲשֶׁר',
#  'תִּרְאֶה',
#  'בַּמָּקוֹם',
#  'יִבְחַר',
#  'נִבְחַר',
#  'בֵּית',
#  'עוֹלָמִים',
#  'רְאוּיָה',
#  'לַשְּׁכִינָה',
#  'מִשֶּׁנִּבְחַר',
#  'בָחַר',
#  'בְּצִיּוֹן',
#  'אִוָּהּ',
#  'לְמוֹשָׁב',
#  'לוֹ',
#  'וְאוֹמֵר',
#  'זֹאת',
#  'מְנוּחָתִי',
#  'עֲדֵי',
#  'כְּשֵׁרִים',
#  'לַכְּהֻנָּה',
#  'בְּרִית',
#  'מֶלַח',
#  'עוֹלָם',
#  'הִוא',
#  'לִפְנֵי',
#  'וְהָיְתָה',
#  'לּוֹ',
#  'וּלְזַרְעוֹ',
#  'אַחֲרָיו',
#  'דָּוִד',
#  'לַמַּלְכוּת',
#  'הֲלֹא',
#  'לָכֶם',
#  'לָדַעַת',
#  'נָתַן',
#  'מַמְלָכָה',
#  'לְדָוִיד',
#  'עַל',
#  'לְעוֹלָם',
#  'וּלְבָנָיו',
#  'תֹּאמַר',
#  'דָּן',
#  'הַנְּבִיאִים',
#  'שֶׁנִּדְבַּר',
#  'עִמָּהֶם',
#  'בְּחוּצָה',
#  'לָאָרֶץ',
#  'פִּי',
#  'בִּזְכוּת',
#  'אָבוֹת',
#  'כֹּה',
#  'אָמַר',
#  'קוֹל',
#  'בְּרָמָה',
#  'נִשְׁמָע',
#  'נְהִי',
#  'בְּכִי',
#  'תַמְרוּרִים',
#  'רָחֵל',
#  'מְבַכָּה',
#  'בָּנֶיהָ',
#  'מֵאֲנָה',
#  'לְהִנָּחֵם',
#  'אֵינֶנּוּ',
#  'מִנְעִי',
#  'קוֹלֵךְ',
#  'מִבֶּכִי',
#  'וְעֵינַיִךְ',
#  'מִדִּמְעָה',
#  'יֵשׁ',
#  'שָׂכָר',
#  'לִפְעֻלָּתֵךְ',
#  'נְאֻם',
#  'וְשָׁבוּ',
#  'מֵאֶרֶץ',
#  'אוֹיֵב',
#  'וְיֵשׁ',
#  'תִּקְוָה',
#  'לְאַחֲרִיתֵךְ',
#  'בָנִים',
#  'לִגְבוּלָם',
#  'אוֹמְרִים',
#  'וּבִזְכוּת',
#  'בְמָקוֹם',
#  'טָהוֹר',
#  'שֶׁלְּמַיִם',
#  'וַאֲנִי',
#  'הָיִיתִי',
#  'אוּבַל',
#  'אוּלָי',
#  'יַד',
#  'הַנָּהָר',
#  'הַגָּדוֹל',
#  'חִדָּקֶל',
#  'הָיֹה',
#  'דְבַר',
#  'יְחֶזְקֵאל',
#  'בּוּזִי',
#  'הַכֹּהֵן',
#  'כַּשְׂדִּים',
#  'נְהַר',
#  'כְּבָר',
#  'בָּאָרֶץ',
#  'וְנִדְבַּר',
#  'חוּצָה',
#  'רַבִּי',
#  'אֶלְעָזָר',
#  'צָדוֹק',
#  'הֲרֵי',
#  'קוּם',
#  'צֵא',
#  'הַבִּקְעָה',
#  'שֶׁהַבִּקְעָה',
#  'שֶׁאֵין',
#  'הַשְּׁכִינָה',
#  'נִגְלֵית',
#  'וַיָּקָם',
#  'יוֹנָה',
#  'לִבְרֹחַ',
#  'תַּרְשִׁישָׁה',
#  'מִלִּפְנֵי',
#  'וְכִי',
#  'בּוֹרֵחַ',
#  'כְבָר',
#  'אָנָה',
#  'אֵלֵךְ',
#  'מֵרוּחֶךָ',
#  'וְאָנָה',
#  'מִפָּנֶיךָ',
#  'אֶבְרָח',
#  'אֶסַּק',
#  'שָׁמַיִם',
#  'שָׁם',
#  'אָתָּה',
#  'וְאַצִּיעָה',
#  'שְּׁאוֹל',
#  'הִנֶּךָ',
#  'אֶשָּׂא',
#  'כַנְפֵי',
#  'שָׁחַר',
#  'אֶשְׁכְּנָה',
#  'בְּאַחֲרִית',
#  'יָם',
#  'גַּם',
#  'יָדְךָ',
#  'תַנְחֵנִי',
#  'וְתֹאחֲזֵנִי',
#  'יְמִינֶךָ',
#  'וּכְתִיב',
#  'עֵינֵי',
#  'הֵמָּה',
#  'מְשׁוֹטְטִים',
#  'צֹפוֹת',
#  'רָעִים',
#  'וטוֹבִים',
#  'יַחְתְּרוּ',
#  'בִשְׁאוֹל',
#  'מִשָּׁם',
#  'יָדִי',
#  'תִקָּחֵם',
#  'וְאִם',
#  'יַעֲלוּ',
#  'אוֹרִידֵם',
#  'יֵחָבְאוּ',
#  'בְּרֹאשׁ',
#  'הַכַּרְמֶל',
#  'אֲחַפֵּשׂ',
#  'וּלְקַחְתִּים',
#  'יִסָּתְרוּ',
#  'מִנֶּגֶד',
#  'עֵינַי',
#  'בְּקַרְקַע',
#  'הַיָּם',
#  'אֲצַוֶּה',
#  'הַנָּחָשׁ',
#  'וּנְשָׁכָם',
#  'יֵלְכוּ',
#  'בַשְּׁבִי',
#  'אֹיבֵיהֶם',
#  'הַחֶרֶב',
#  'וַהֲרָגָתַם',
#  'וְשַׂמְתִּי',
#  'עֵינִי',
#  'עֲלֵיהֶם',
#  'לְרָעָה',
#  'לְטוֹבָה',
#  'חשֶׁךְ',
#  'וְאֵין',
#  'צַלְמָוֶת',
#  'לְהִסָּתֶר',
#  'פֹּעֲלֵי',
#  'אָוֶן',
#  'לְחוּצָה',
#  'שֶׁהַגּוֹיִם',
#  'קְרוֹבֵי',
#  'תְּשׁוּבָה',
#  'הֵן',
#  'לְחַיֵּב',
#  'מָשָׁל',
#  'לְעֶבֶד',
#  'כֹּהֵן',
#  'שֶׁבָּרַח',
#  'מֵרַבּוֹ',
#  'לְבֵית',
#  'הַקְּבָרוֹת',
#  'יָכֹל',
#  'לָבֹא',
#  'אַחֲרַי',
#  'רַבּוֹ',
#  'כְּנָיוֹת',
#  'בָּךְ',
#  'הַקֹּדֶשׁ',
#  'בָּרוּךְ',
#  'שְׁלוּחִין',
#  'וַיי',
#  'הֵטִיל',
#  'רוּחַ',
#  'גְּדוֹלָה',
#  'שְׁלֹשָׁה',
#  'הֵם',
#  'אֶחָד',
#  'תָּבַע',
#  'כְּבוֹד',
#  'הָאָב',
#  'וּכְבוֹד',
#  'הַבֵּן',
#  'וְאֶחָד',
#  'כְבוֹד',
#  'יִרְמְיָה',
#  'נַחְנוּ',
#  'פָשַׁעְנוּ',
#  'וּמָרִינוּ',
#  'סָלָחְתָּ',
#  'לְכָךְ',
#  'נִכְפְּלָה',
#  'נְבוּאָתוֹ',
#  'וְעוֹד',
#  'נוֹסַף',
#  'אֵלִיָּהוּ',
#  'קַנֹּא',
#  'קִנֵּאתִי',
#  'צְבָאוֹת',
#  'עָזְבוּ',
#  'בְרִיתְךָ',
#  'בְּנֵי',
#  'מִזְבְּחֹתֶיךָ',
#  'הָרָסוּ',
#  'נְבִיאֶיךָ',
#  'הָרְגוּ',
#  'בֶחָרֶב',
#  'וָאִוָּתֵר',
#  'לְבַדִּי',
#  'וַיְבַקְשׁוּ',
#  'נַפְשִׁי',
#  'לְקַחְתָּהּ',
#  'נֶּאֱמַר',
#  'לֵךְ',
#  'שׁוּב',
#  'לְדַרְכְּךָ',
#  'מִדְבַּרָה',
#  'דַמָּשֶׂק',
#  'וּבָאתָ',
#  'וּמָשַׁחְתָּ',
#  'חֲזָאֵל',
#  'לְמֶלֶךְ',
#  'אֲרָם',
#  'יֵהוּא',
#  'בֶן',
#  'נִמְשִׁי',
#  'תִּמְשַׁח',
#  'אֱלִישָׁע',
#  'שָׁפָט',
#  'מֵאָבֵל',
#  'מְחוֹלָה',
#  'לְנָבִיא',
#  'תַּחְתֶּיךָ',
#  'אֶפְשִׁי',
#  'בִנְבוּאָתָךְ',
#  'וַיֵּרֶד',
#  'יָפוֹ',
#  'וַיִּמְצָא',
#  'אָנִיָּה',
#  'בָּאָה',
#  'תַרְשִׁישׁ',
#  'וַיִּתֵּן',
#  'שְׂכָרָהּ',
#  'בָּהּ',
#  'לָבוֹא',
#  'כתִיב',
#  'שֵׁנִית',
#  'שְׁלִישִׁית',
#  'נָתָן',
#  'הָלַךְ',
#  'לְאַבֵּד',
#  'עַצְמוֹ',
#  'בַּיָּם',
#  'אֲלֵיהֶם',
#  'שָׂאוּנִי',
#  'וַהֲטִילֻנִי',
#  'וְכֵן',
#  'תִּמְצָא',
#  'הָאָבוֹת',
#  'וְהַנְּבִיאִים',
#  'נוֹתְנִים',
#  'עַצְמָם',
#  'בְּמֹשֶׁה',
#  'וְעַתָּה',
#  'תִּשָּׂא',
#  'חַטָּאתָם',
#  'אַיִן',
#  'מְחֵנִי',
#  'נָא',
#  'מִסִּפְרְךָ',
#  'כָּתָבְתָּ',
#  'כָּכָה',
#  'אַתְּ',
#  'עֹשֶׂה',
#  'לִּי',
#  'הָרְגֵנִי',
#  'הָרֹג',
#  'מָצָאתִי',
#  'חֵן',
#  'בְּעֵינֶיךָ',
#  'וְאַל',
#  'אֶרְאֶה',
#  'בְּרָעָתִי',
#  'בְּדָוִד',
#  'מַהוּ',
#  'הִנֵּה',
#  'חָטָאתִי',
#  'וְאָנֹכִי',
#  'הֶעֱוֵיתִי',
#  'וְאֵלֶּה',
#  'הַצֹּאן',
#  'מֶה',
#  'עָשׂוּ',
#  'תְּהִי',
#  'בִּי',
#  'וּבְבֵית',
#  'אָבִי',
#  'הָא',
#  'מוֹצֵא',
#  'נָתְנוּ',
#  'נַפְשָׁם',
#  'וֶאֱמֹר',
#  'מִיָּד',
#  'דִּבְרֵי',
#  'יִשְׁמָעֵאל',
#  'וְיָצָא',
#  'וְדִבֶּר',
#  'אֱלִיעֶזֶר',
#  'וַהֲשִׁיבֵנִי',
#  'דָבָר',
#  'וַיָּשֶׁב',
#  'הָעָם',
#  'וְהִנֵּה',
#  'הָאִישׁ',
#  'לְבֻשׁ',
#  'הַבַּדִּים',
#  'הַקֶּסֶת',
#  'בְּמָתְנָיו',
#  'מֵשִׁיב',
#  'הַתְשַׁלַּח',
#  'בְּרָקִים',
#  'וְיֵלֵכוּ',
#  'וְיֹאמְרוּ',
#  'הִנֵּנוּ',
#  'שְׁלוּחֵי',
#  'כִשְׁלוּחֵי',
#  'בָשָׂר',
#  'וָדָם',
#  'שֶׁשְּׁלוּחֵי',
#  'צְרִיכִין',
#  'לַחְזֹר',
#  'אֵצֶל',
#  'שׁוֹלְחֵיהֶם',
#  'אֲבָל',
#  'לְפָנֶיךָ',
#  'כֵן',
#  'וְיָשׁוּבוּ',
#  'שֶׁהֵן',
#  'מְהַלְּכִין',
#  'נִמְצָאִים',
#  'וְאוֹמְרִים',
#  'עָשִׂינוּ',
#  'שְׁלִיחוּתָךְ',
#  'לְקַיֵּם',
#  'שֶּׁנֶּאֱמַר',
#  'הֲלוֹא',
#  'מָלֵא',
#  'יֹאשִׁיָּה',
#  'כְּשֶׁהַקֹּדֶשׁ',
#  'גּוֹזֵר',
#  'גְּזֵרוֹת',
#  'טוֹבוֹת',
#  'וְרָעוֹת',
#  'הַטּוֹבָה',
#  'מַחְזִירִים',
#  'לְפָנָיו',
#  'וְעַל',
#  'הָרָעָה',
#  'שִׁשָּׁה',
#  'אֲנָשִׁים',
#  'בָּאִים',
#  'מִדֶּרֶךְ',
#  'שַׁעַר',
#  'הָעֶלְיוֹן',
#  'מָפְנֶה',
#  'צָפוֹנָה',
#  'וְאִישׁ',
#  'כְּלִי',
#  'מַפָּצוֹ',
#  'בְּיָדוֹ',
#  'בְּתוֹכָם',
#  'לָבֻשׁ',
#  'בַּדִּים',
#  'וְקֶסֶת',
#  'הַסֹּפֵר',
#  'וַיָּבֹאוּ',
#  'וַיַּעַמְדוּ',
#  'מִזְבַּח',
#  'הַנְּחֹשֶׁת',
#  'נַעֲלָה',
#  'מֵעַל',
#  'הַכְּרוּב',
#  'אֵלָו',
#  'עֲבֹר',
#  'יְרוּשָׁלִָם',
#  'וְהִתְוִיתָ',
#  'תָּו',
#  'מִצְחוֹת',
#  'הָאֲנָשִׁים',
#  'הַנֶּאֱנָחִים',
#  'וְהַנֶּאֱנָקִים',
#  'הַתּוֹעֵבוֹת',
#  'הַנַּעֲשׂוֹת',
#  'בְּתוֹכָהּ',
#  'וּלְאֵלֶּה',
#  'בְּאָזְנַי',
#  'וְנֶאֱמַר',
#  'זָקֵן',
#  'בָּחוּר',
#  'וּבְתוּלָה',
#  'וְטַף',
#  'וְנָשִׁים',
#  'תַּהַרְגוּ',
#  'לְמַשְׁחִית',
#  'עָלָיו',
#  'הַתָּו',
#  'אַל',
#  'תִּגַּשׁוּ',
#  'וּמִמִּקְדָּשִׁי',
#  'תָּחֵלּוּ',
#  'וַיָּחֵלּוּ',
#  'בָּאֲנָשִׁים',
#  'הַזְּקֵנִים',
#  'הַבָּיִת',
#  'טַמְּאוּ',
#  'הַבַּיִת',
#  'וּמַלְאוּ',
#  'הַחֲצֵרוֹת',
#  'חֲלָלִים',
#  'צֵאוּ',
#  'וְיָצְאוּ',
#  'וְהִכּוּ',
#  'בָעִיר',
#  'אֵלּוּ',
#  'וָאֵלּוּ',
#  'וְעָשׂוּ',
#  'שְׁלִיחוּתָן',
#  'שֶׁנִּצְטַוּוּ',
#  'לָמַדְנוּ',
#  'שֶׁהֶחְזִירוּ',
#  'וְזֶה',
#  'שֶׁנִּצְטַוָּה',
#  'שֶׁהֶחְזִיר',
#  'שְׁלִיחוּתוֹ',
#  'עָשִׂיתִי',
#  'כַאֲשֶׁר',
#  'צִוִּיתָנִי',
#  'שִׁמְעוֹן',
#  'עַזַּי',
#  'בַּקּוֹל',
#  'שֶׁאַתָּה',
#  'בּוֹ',
#  'לָמֵד',
#  'עֲקִיבָה',
#  'לָהֶם',
#  'שֶׁבִּזְכוּתָם',
#  'מְדַבֵּר',
#  'עִמִּי',
#  'שֶׁכָּל',
#  'שְׁלֹשִׁים',
#  'וּשְׁמֹנֶה',
#  'שָׁנָה',
#  'כוֹעֵס',
#  'תַּמּוּ',
#  'אַנְשֵׁי',
#  'הַמִּלְחָמָה',
#  'לָמוּת',
#  'מִקֶּרֶב',
#  'וַיְדַבֵּר',
#  'אֵלַי',
#  'אֵינִי',
#  'כְמֵשִׁיב',
#  'כְּמוֹסִיף',
#  'עִם',
#  'בִּלְבַד',
#  'כֻּלָּם',
#  'דִבֵּר',
#  'וָאֵשֵׁב',
#  'שִׁבְעַת',
#  'יָמִים',
#  'מַשְׁמִים',
#  'מִקְצֵה',
#  'מִקֵּץ',
#  'עֲשֶׂרֶת',
#  'יִרְמְיָהוּ',
#  'בְּבָרוּךְ',
#  'נֵרִיָּה',
#  'מִתְרָעֵם',
#  'הַמָּקוֹם',
#  'אָמַרְתָּ',
#  'אוֹי',
#  'יָסַף',
#  'יָגוֹן',
#  'מַכְאֹבִי',
#  'נִּשְׁתַּנֵּיתִי',
#  'תַּלְמִידֵי',
#  'יְהוֹשֻׁעַ',
#  'שִׁמֵּשׁ',
#  'וְשָׁרְתָה',
#  'יָגַעְתִּי',
#  'בְּאַנְחָתִי',
#  'וּמְנוּחָה',
#  'מְנוּחָה',
#  'נְבוּאָה',
#  'וַתָּנַח',
#  'עֲלֵהֶם',
#  'הָרוּחַ',
#  'נָחָה',
#  'וְנָחָה',
#  'בֹּא',
#  'וּרְאֵה',
#  'מְשִׁיבוֹ',
#  'בָּנִיתִי',
#  'הֹרֵס',
#  'נָטַעְתִּי',
#  'נֹתֵשׁ',
#  'הִיא',
#  'וְאַתָּה',
#  'תְּבַקֶּשׁ',
#  'גְדֹלוֹת',
#  'תְּבַקֵּשׁ',
#  'גְּדוֹלוֹת',
#  'סַפְּרָה',
#  'נָּא',
#  'הַגְּדֹלוֹת',
#  'עָשָׂה',
#  'קְרָא',
#  'וְאֶעֱנֶךָּ',
#  'וְאַגִּידָה',
#  'לְּךָ',
#  'גְּדֹלוֹת',
#  'וּבְצֻרוֹת',
#  'יְדַעְתָּם',
#  'כֶּרֶם',
#  'סְיָג',
#  'צֹאן',
#  'רוֹעֶה',
#  'הִנְנִי',
#  'מֵבִיא',
#  'רָעָה',
#  'בָּשָׂר',
#  'וְנָתַתִּי',
#  'נַפְשְׁךָ',
#  'לְשָׁלָל',
#  'הַמְּקֹמוֹת',
#  'תֵּלֶךְ',
#  'מִתְנַּבְּאִים',
#  'בִּזְכוּתָן',
#  'שֶׁלְּיִשְׂרָאֵל',
#  'הַחֹדֶשׁ',
#  'הַזֶּה',
#  'רֹאשׁ',
#  'חֳדָשִׁים',
#  'רִאשׁוֹן',
#  'לְחָדְשֵׁי',
#  'הַשָּׁנָה',
#  'הֶרְאָה',
#  'לְיִשְׂרָאֵל',
#  'וְאָמַר',
#  'הֱיוּ',
#  'רוֹאִין',
#  'וְקוֹבְעִין',
#  'לַדּוֹרוֹת',
#  'דְבָרִים',
#  'שֶׁנִּתְקַשָּׁה',
#  'בָהֶן',
#  'וְהֶרְאָהוּ',
#  'כֻּלָּן',
#  'בָּאֶצְבַּע',
#  'הַטָּמֵא',
#  'מַעֲשֵׂה',
#  'הַמְּנֹרָה',
#  'בַּשְּׁחִיטָה',
#  'נִתְקַשָּׁה',
#  'תַּעֲשֶׂה',
#  'הַמִּזְבֵּחַ',
#  'יוֹחַי',
#  'בַיּוֹם',
#  'וְהַחֹדֶשׁ',
#  'הראהו',
#  'בַּלַּיְלָה',
#  'וְכֵיצַד',
#  'בַּיּוֹם',
#  'חֲשֵׁכָה',
#  'בַּחֲשֵׁכָה',
#  'נִיסָן',
#  'מֵחָדְשֵׁי',
#  'וְחַג',
#  'הָאָסִף',
#  'בְּצֵאת',
#  'הָאָסִיף',
#  'תְּקוּפַת',
#  'אֵי',
#  'חֹדֶשׁ',
#  'שֶׁיֵּשׁ',
#  'אָסִיף',
#  'וּתְקוּפָה',
#  'וְשָׁנָה',
#  'יוֹצְאָה',
#  'בוֹ',
#  'וְקָרוּי',
#  'שְׁבִיעִי',
#  'תִּשְׁרִי',
#  'לְאַחַר',
#  'שֶׁלָּמַדְתָּ',
#  'שֶׁשְּׁבִיעִי',
#  'רְאָיָה',
#  'לַדָּבָר',
#  'זֵכֶר',
#  'בַּחֹדֶשׁ',
#  'הָרִאשׁוֹן',
#  'שֶׁנִּיסָן',
#  'לֶחֳדָשִׁים',
#  'וּמְנַיִן',
#  'לַמְּלָכִים',
#  'הַשֵּׁנִי',
#  'לִמְלֹךְ',
#  'שְׁלֹמֹה',
#  'לָרְגָלִים',
#  'חַג',
#  'בְּחַג',
#  'הַמַּצּוֹת',
#  'וּבְחַג',
#  'הַשָּׁבֻעוֹת',
#  'הַסֻּכּוֹת',
#  'נִמְצֵינוּ',
#  'לְמֵדִין',
#  'וְלָרְגָלִים',
#  'וְרַבִּי',
#  'לִשְׂכִירוּת',
#  'בָּתִּים',
#  'לַשָּׁנִים',
#  'לַשְּׁמִטִּין',
#  'לַיּוֹבְלוֹת',
#  'לַנְּטִיעָה',
#  'לַיְּרָקוֹת',
#  'שֶׁבַע',
#  'שָׁנִים',
#  'בְּמֹעֵד',
#  'שְׁנַת',
#  'הַשְּׁמִטָּה',
#  'בְּבוֹא',
#  'לֵרָאוֹת',
#  'פְּנֵי',
#  'אֱלֹהֶיךָ',
#  'יִבְחָר',
#  'תִּקְרָא',
#  'הַתּוֹרָה',
#  'הַזֹּאת',
#  'נֶגֶד',
#  'בְּאָזְנֵיהֶם',
#  'הָאָמוּר',
#  'לָךְ',
#  'לַשְּׁמִטִּים',
#  'וְלַיּוֹבְלוֹת',
#  'וְלַיְּרָקוֹת',
#  'מָנָה',
#  'אָדָם',
#  'לַגּוֹיִם',
#  'אָמוּר',
#  'שֶׁיִּשְׂרָאֵל',
#  'מוֹנִין',
#  'לַלְּבָנָה',
#  'וְהַגּוֹיִם',
#  'לַחַמָּה',
#  'דַּיָּם',
#  'אַחַת',
#  'לִשְׁלֹשִׁים',
#  'יוֹם',
#  'מַגְבִּיהִים',
#  'עֵינֵיהֶם',
#  'לַאֲבִיהֶם',
#  'שֶׁבַּשָּׁמַיִם',
#  'וּכְשֶׁהַחַמָּה',
#  'לוֹקָה',
#  'סִימָן',
#  'רַע',
#  'שֶׁהֵם',
#  'מוֹנִים',
#  'וּכְשֶׁהַלְּבָנָה',
#  'לְשׂוֹנְאֵיהֶם',
#  'מֵאִיר',
#  'כְּשֶׁהַחַמָּה',
#  'בַּמִּזְרָח',
#  'לְיוֹשְׁבֵי',
#  'מִזְרָח',
#  'בַּמַּעֲרָב',
#  'מַעֲרָב',
#  'כְּשֶׁהַמַּזָּלוֹת',
#  'לוֹקִים',
#  'יוֹנָתָן',
#  'נִתְּנוּ',
#  'דֶּרֶךְ',
#  'הַגּוֹיִם',
#  'תִּלְמָדוּ',
#  'וּמֵאֹתוֹת',
#  'תֵּחָתּוּ',
#  'מִעוּט',
#  'שְׁנַיִם',
#  'לִשְׁאָר',
#  'שָׁמוֹר',
#  'הָאָבִיב',
#  'וְעָשִׂיתָ',
#  'פֶּסַח',
#  'הַפֶּסַח',
#  'לָאָבִיב',
#  'וְאָבִיב',
#  'לַפֶּסַח',
#  'שֶׁיָּבֹא',
#  'אָבִיב',
#  'בִּזְמַנּוֹ',
#  'כֵּיצַד',
#  'עַבֵַּר',
#  'אֲדָר',
#  'שֶׁעִבְּרוּ',
#  'בָא',
#  'יְעַבְּרוּ',
#  'עוֹשֶׂה',
#  'שֵׁנִי',
#  'וְאָמְרָה',
#  'תּוֹרָה',
#  'הַסָּמוּךְ',
#  'מְעַבֵּר',
#  'וְאֵי',
#  'הֱוֵי',
#  'שָׁמַעְנוּ',
#  'מִכַּמָּה',
#  'וְהַדִּין',
#  'נוֹתֵן',
#  'הוֹאִיל',
#  'וְחֹדֶשׁ',
#  'מִתְעַבֵּר',
#  'מִתְעַבֶּרֶת',
#  'מִמְּנוּיָיו',
#  'מִמְּנוּיֶיהָ',
#  'אִי',
#  'מִשְּׁלֹשִׁים',
#  'שָּׁנָה',
#  'מִשְּׁנֵים',
#  'עָשָׂר',
#  'וּבַחֲמִשָּׁה',
#  'לַחֹדֶשׁ',
#  'מַצּוֹת',
#  'תֹּאכֵלוּ',
#  'לְחֹדֶשׁ',
#  'כְּבַר',
#  'הַלְּבָנָה',
#  'בְּאֶמְצַע',
#  'הָרָקִיעַ',
#  'עָלֶיךָ',
#  'כַּלָּשׁוֹן',
#  'הָאַחֲרוֹן',
#  'וְהַשָּׁנָה',
#  'תּוֹסֶפֶת',
#  'עִבּוּרוֹ',
#  'ַסּוֹף',
#  'עִבּוּרָהּ',
#  'בַסּוֹף',
#  'וְטֻמְאָה',
#  'מְעַכֶּבֶת',
#  'מְעַכֵּב',
#  'טֻּמְאָה',
#  'פָּחוּת',
#  'אֲפִלּוּ',
#  'חָל',
#  'וּבָא',
#  'וְשָׁמַרְתָּ',
#  'הַחֻקָּה',
#  'לְמוֹעֲדָהּ',
#  'בְּמוֹעֲדָהּ',
#  'מוֹסִיף',
#  ...]
